# %%
class Dragon:
    def __init__(self,type):
        self.type = type

water_dragon = Dragon("water")
fire_dragon = Dragon("fire")
ice_dragon = Dragon("ice")

print("All Available Dragons:")
print(f'1. {water_dragon.type} Dragon')
print(f'2. {fire_dragon.type} Dragon')
print(f'3. {ice_dragon.type} Dragon')
# Out:
# All Available Dragons:
# 1. water Dragon
# 2. fire Dragon
# 3. ice Dragon

# %%
class Pokemon:
    def __init__(self,name,type='normal',hp=10,atk=10,dfn=10):
        self.name = name
        self.type = type
        self.hp = hp
        self.atk = atk
        self.dfn = dfn

    def stats(self):
        print("Pokemon Details")
        print(f'Name: {self.name}')
        print(f'Type: {self.type}')
        print(f'HP: {self.hp}')
        print(f'Attack: {self.atk}')
        print(f'Denfense: {self.dfn}')

    def overall(self):
        return self.hp + self.atk + self.dfn
    def is_powerfull(self):
        if self.overall()>100:
            return True
        return False

# %%
pikachu = Pokemon("pikachu","Electric", 35,55,40)
snorlax = Pokemon("snorlax","Normal",160,110,65)
charizard = Pokemon("charizard","fire/flying",78,84,78)
bulbasaur = Pokemon("bulbasaur","grass/poison",45,49,49)
rattata = Pokemon("rattata")

pokemons = [pikachu,snorlax,charizard,bulbasaur,rattata]
print("\nStats:")
for poke in pokemons:
    poke.stats()
    print(f'Overall Score: { poke.overall()}')
    print(f'Is powerfull:{poke.is_powerfull()}')
    print('-----------------------')
# Out:
# Stats:
# Pokemon Details
# Name: pikachu
# Type: Electric
# HP: 35
# Attack: 55
# Denfense: 40
# Overall Score: 130
# Is powerfull:True
# -----------------------
# Pokemon Details
# Name: snorlax
# Type: Normal
# HP: 160
# Attack: 110
# Denfense: 65
# Overall Score: 335
# Is powerfull:True
# -----------------------
# Pokemon Details
# Name: charizard
# Type: fire/flying
# HP: 78
# Attack: 84
# Denfense: 78
# Overall Score: 240
# Is powerfull:True
# -----------------------
# Pokemon Details
# Name: bulbasaur
# Type: grass/poison
# HP: 45
# Attack: 49
# Denfense: 49
# Overall Score: 143
# Is powerfull:True
# -----------------------
# Pokemon Details
# Name: rattata
# Type: normal
# HP: 10
# Attack: 10
# Denfense: 10
# Overall Score: 30
# Is powerfull:False
# -----------------------

# %%
class Calc:
    def run(self,numl,operator,num2):
        match operator:
            case '+': return self.add(numl,num2)
            case '-': return self.subtract(numl,num2)
            case '*': return self.multiply(numl,num2)
            case '/': return self.divide(numl,num2)
    def add(self,a,b): return a + b
    def multiply(self,a,b): return a * b 
    def subtract(self,a,b): return  a - b
    def divide(self,a, b):
        if b==0: return "⚠️ can't divide by 0"
        return a/b

# %%
c = Calc()
while True:
    a = int(input("enter first num"))
    b= int(input("enter next num"))
    op= input("enter operation(+,-,*,/)")
    ans= c.run(a,op,b)
    print(ans)
    if input('continue')!='Y':
        break
# Out:
# 15
